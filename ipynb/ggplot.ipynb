# %% [markdown]
# # Setup

# %%
from functools import partial
from rpy2.ipython import html
from rpy2.robjects import pandas2ri
import pandas as pd

# %%
html.html_rdataframe=partial(html.html_rdataframe, table_class="docutils") # for better display
html.init_printing() # for better display
pandas2ri.activate() # for better conversion

# %%
dataf = pd.read_csv('https://raw.githubusercontent.com/tpemartin/112-2-programming-for-economic-modeling/main/data/cities.csv')

# %% [markdown]
# > If you encounter CERTIFICATE_VERIFY_FAILED error, please run the following command in your Terminal to fix it.
# >
# > ```bash
# > sudo /Applications/Python*/Install\ Certificates.command
# >```
#
# ```python
# import ssl
# ssl._create_default_https_context = ssl._create_unverified_context
# ```

# %%
type(dataf)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # reference

# %%
from functools import partial
from rpy2.ipython import html
html.html_rdataframe=partial(html.html_rdataframe, table_class="docutils")

# %%
from rpy2.robjects.packages import importr
utils = importr('utils')

dataf = utils.read_csv(('https://raw.githubusercontent.com/jakevdp/PythonDataScienceHandbook/'
                       'master/notebooks_v1/data/california_cities.csv'))

type(dataf)
# Out:
# rpy2.robjects.vectors.DataFrame

# %%
# download and read the CSV file in Python
from rpy2.robjects import pandas2ri
import pandas as pd
pandas2ri.activate()
dataf = pd.read_csv((
    "https://raw.githubusercontent.com/tpemartin/112-2-programming-for-economic-modeling"
    "/main/data/cities.csv"
))

type(dataf)
# Out:
# pandas.core.frame.DataFrame

# %%
import rpy2.ipython.html
rpy2.ipython.html.init_printing()

# %%
dataf
# Out:
#      obs          city       latd       longd  elevation_m  elevation_ft  \
# 0       0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1       1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2       2      Alameda  37.756111 -122.274444          NaN          33.0
# 3       3       Albany  37.886944 -122.297778          NaN          43.0
# 4       4     Alhambra  34.081944 -118.135000        150.0         492.0
# ..    ...          ...        ...         ...          ...           ...
# 477   477   Yountville  38.403056 -122.362222         30.0          98.0
# 478   478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479   479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480   480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481   481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# ...

# %%
stats = importr('stats')
base = importr('base')
fit = stats.lm('elevation_m ~ latd + longd', data=dataf)
fit
# Out:
# <rpy2.robjects.vectors.ListVector object at 0x166de49d0> [19]
# R classes: ('lm',)
# [FloatSexp..., FloatSexp..., FloatSexp..., IntSexpVe..., ..., ListSexpV..., LangSexpV..., LangSexpV..., ListSexpV...]
#   coefficients: <class 'numpy.ndarray'>
#   array([16206.30871117,   172.50868496,   185.7326372 ])
#   residuals: <class 'numpy.ndarray'>
#   array([ 5.15111340e+02,  2.40862217e+02,  5.78496741e+00, -5.80990958e+00,
#         3.57461560e+02, -1.13005437e+02, -7.03505533e+01, -9.93627360e+01,
#        -3.38185950e+02,  3.47336625e+01, -1.26182632e+02,  5.08227137e+02,
#        -2.42995258e+01,  1.67922127e+02, -1.01285695e+02, -7.28960273e+01,
#         3.53186023e+02,  4.62838114e+01, -2.02066146e+02, -5.51810966e+01,
#         2.84381957e+01,  1.40515181e+02, -8.95823120e+00, -6.06951206e+01,
#         3.67865051e+02,  1.70952280e+02,  4.63295183e+02, -7.52266820e+01,
#        -9.01605101e+01, -8.36471878e+01,  4.80546202e+01,  1.69524285e+01,
# ...

# %%
import rpy2.robjects.lib.ggplot2 as gp

# %%
from rpy2.robjects import rl

# %%
p = (gp.ggplot(dataf) +
     gp.aes(x=rl('longd'),
            y=rl('latd'),
            color=rl('population_total'),
            size=rl('area_total_km2')) +
     gp.geom_point() +
     gp.scale_color_continuous(trans='log10'))

# %%
from rpy2.ipython.ggplot import image_png
image_png(p)
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: Removed 5 rows containing missing values (`geom_point()`).
